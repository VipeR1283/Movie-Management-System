# %%
class Kullanici:
    def __init__(self, ad, soyad, email, kullanici_adi, sifre):
        self.ad = ad
        self.soyad = soyad
        self.email = email
        self.kullanici_adi = kullanici_adi
        self.sifre = sifre
    def bilgileri_goster(self):
        print(50*"#")
        print(f""" 
        Ad: {self.ad}
        Soyad: {self.soyad}
        E-mail: {self.email}
        Kullanici Adi: {self.kullanici_adi}
        Sifre: ******
        """)
    def bilgileri_guncelle(self):
        print("Yeni bilgileri guncellemezseniz eski bilgiler gecerli olacaktir.")
        yeni_ad = input("Yeni adi girin: ")
        yeni_soyad = input("Yeni soyadini girin: ")
        yeni_email = input("Yeni mail adresini girin: ")
        yeni_kadi = input("Yeni kullanici adini girin: ")
        yeni_sifre = input("Yeni sifrenizi girin:")
        if yeni_ad:
            self.ad = yeni_ad
        if yeni_soyad:
            self.soyad = yeni_soyad
        if yeni_email:
            self.email = yeni_email
        if yeni_kadi:
            self.kullanici_adi = yeni_kadi
        if yeni_sifre:
            self.sifre = yeni_sifre
        print("Bilgileriniz Guncellendi.")
class Yonetmen:
    def __init__(self, yonetmen_ad_soyad, d_yili):
        self.yonetmen_ad_soyad = yonetmen_ad_soyad
        self.d_yili = d_yili
    def bilgileri_goster(self):
        print(50*"#")
        print(f""" 
        Yonetmen Adi ve Soyadi: {self.yonetmen_ad_soyad}
        Yonetmen Dogum Yili: {self.d_yili}    
            """)
    def bilgileri_guncelle(self):
        print("Bilgileri guncellemezseniz eski bilgiler gecerli olacaktir.")
        yeni_ad_soyad = input("Yeni ad soyad bilgilerini girin: ")
        yeni_d_yili = input("Yeni dogum yilini girin: ")
        if yeni_ad_soyad:
            self.yonetmen_ad_soyad = yeni_ad_soyad
        if yeni_d_yili:
            self.d_yili = yeni_d_yili
        print("Yonetmen bilgileri basarili sekilde guncellendi.")
class Film:
    def __init__(self, film_adi, yonetmen_ad_soyad, cikis_yili, tur):
        self.film_adi = film_adi
        self.yonetmen_ad_soyad = yonetmen_ad_soyad
        self.cikis_yili = cikis_yili
        self.tur = tur
    def bilgileri_goster(self):
        print(50*"#")
        print(f""" 
        Film Adi: {self.film_adi}
        Yonetmeni: {yonetmen_ad_soyad}
        Yapim Yili: {self.cikis_yili}
        Turu: {self.tur}
        """)
    def bilgileri_guncelle(self):
        print("Bilgileri guncellemezseniz eski bilgiler gecerli olacaktir.")
        yeni_film_ad = input("Filmin yeni adini girin: ")
        yeni_yonetmen_ad_soyad = input("Filmin yeni yonetmenini girin: ")
        yeni_cikis_yili = input("Filmin cikis yilini guncelleyin: ")
        yeni_tur = input("Filmin turunu guncelleyin: ")
        if yeni_film_ad:
            self.film_adi = yeni_film_ad
        if yeni_yonetmen_ad_soyad:
            yonetmen = next((yonetmen for yonetmen in film_kutuphanesi.yonetmenler if yonetmen.yonetmen_ad_soyad == yeni_yonetmen_ad_soyad), None)
            if yonetmen:
                self.yonetmen_ad_soyad = yeni_yonetmen_ad_soyad
            else:
                print("Yonetmen bilgileri bulunamadi. Yonetmeni sisteme ekleyin ve sonra tekrar guncelleme yapin.")
        if yeni_cikis_yilicikis_yili:
            self.cikis_yili = yeni_cikis_yili
        if yeni_tur:
            self.tur = yeni_tur
        print("Bilgiler basarili sekilde guncellendi.")
class FKutuphanesi:
    def __init__(self):
        self.kullanicilar = []
        self.filmler = []
        self.yonetmenler = []
    def kullanici_ekle(self, kullanici):
        self.kullanicilar.append(kullanici)
        print(f"{kullanici.kullanici_adi} basarili sekilde eklendi.")
    def yonetmen_ekle(self, yonetmen):
        self.yonetmenler.append(yonetmen)
        print(f"{yonetmen.yonetmen_ad_soyad} basarili sekilde eklendi.")
    def film_ekle(self, film):
        self.filmler.append(film)
        print(f"{film.film_adi} basarili sekilde eklendi.")
    def kullanici_goster(self):
        print("Kullanicilar: ")
        for kullanici  in self.kullanicilar:
            kullanici.bilgileri_goster()
    def yonetmen_goster(self):
        print("Yonetmenler: ")
        for yonetmen in self.yonetmenler:
            yonetmen.bilgileri_goster()
    def film_goster(self):
        print("Filmler: ")
        for film in self.filmler:
            film.bilgileri_goster()
    def kullanici_sil(self, kullanici_adi):
        kullanici = next((kullanici for kullanici in self.kullanicilar if kullanici.kullanici_adi == kullanici_adi), None)
        if kullanici:
            self.kullanicilar.remove(kullanici)
            print(f"{kullanici_adi} basarili sekilde silindi.")
        else:
            print("İlgili kullanici bulunamadi.")
    def yonetmen_sil(self, yonetmen_ad_soyad):
        yonetmen = next((yonetmen for yonetmen in self.yonetmenler if yonetmen.yonetmen_ad_soyad == yonetmen_ad_soyad), None)
        if yonetmen:
            self.yonetmenler.remove(yonetmen)
            print(f"{yonetmen_ad_soyad} basarili sekilde silindi.")
        else:
            print("İlgili yonetmen bulunamadi.")
    def film_sil(self, film_adi):
        film = next((film for film in self.filmler if film.film_adi == film_adi), None)
        if film:
            self.filmler.remove(film)
            print(f"{film_adi} basarili sekilde silindi.")
    def film_aramak(self, film_adi):
        for film in self.filmler:
            if film.film_adi.lower() == film_adi:
                return film
        return None
    def kullanici_guncelleme(self, kullanici_adi):
        kullanici = next((kullanici for kullanici in self.kullanicilar if kullanici.kullanici_adi == kullanici_adi), None)
        if kullanici:
            kullanici.bilgileri_guncelle()
        else:
            print("Kullanici tespit edilemedi.")
    def yonetmen_guncelleme(self, yonetmen_ad_soyad):
        yonetmen = next((yonetmen for yonetmen in self.yonetmenler if yonetmen.yonetmen_ad_soyad == yonetmen_ad_soyad), None)
        if yonetmen:
            yonetmen.bilgileri_guncelle()
        else:
            print("Yonetmen tespit edilemedi.")
    def film_guncelleme(self, film_adi):
        film = next((film for film in self.filmler if film.film_adi == film_adi), None)
        if film:
            film.bilgileri_guncelle
        else:
            print("Film tespit edilemedi.")    
film_kutuphanesi = FKutuphanesi()
while True:
    print(50 * "*", "Film Yonetim Sistemi", 50 * "*")
    print(""" 
        Lütfen yapacaginiz islemin numarasini girin:
        
        1. Kullanici Ekle
        2. Yonetmen Ekle
        3. Film Ekle
        4. Kullanici Listesi
        5. Yonetmen Listesi
        6. Film Listesi
        7. Kullanici Sil
        8. Yonetmen Sil
        9. Film Sil
        10. Kullanici Guncelleme
        11. Yonetmen Guncelleme
        12. Film Guncelleme 
        13. Film Arama
        14. Cikis icin (Q-q)
    """)
    islem = input("İslem numarasini girin: ")
    if islem == "1":
        ad = input("Ad: ")
        soyad = input("Soyad: ")
        email = input("E-mail: ")
        kadi = input("Kullanici Adi: ")
        sifre = input("Sifre: ")
        kullanici = Kullanici(ad, soyad, email, kadi, sifre)
        film_kutuphanesi.kullanici_ekle(kullanici)
    elif islem == "2":
        ad_soyad = input("Yonetmen adini ve soyadini girin: ")
        dogum_yili = input("Yonetmen dogum yilini girin: ")
        yonetmen = Yonetmen(ad_soyad, dogum_yili)
        film_kutuphanesi.yonetmen_ekle(yonetmen)
    elif islem == "3":
        film_adi = input("Film adini girin: ")
        yonetmen_ad_soyad = input("Film yonetmeninin adini soyadini girin: ")
        cikis_yili = input("Film yapim yilini girin: ")
        tur = input("Film turunu girin: ")
        yonetmen = next((yonetmen for yonetmen in film_kutuphanesi.yonetmenler if yonetmen.yonetmen_ad_soyad == yonetmen_ad_soyad), None)
        if yonetmen:
            film = Film(film_adi, yonetmen_ad_soyad, cikis_yili, tur)
            film_kutuphanesi.film_ekle(film)
        else:
            print("Yonetmen bilgileri bulunamadi. Yonetmeni sisteme ekleyin ve sonra tekrar guncelleme yapin.")
    elif islem == "4":
        film_kutuphanesi.kullanici_goster()
    elif islem == "5":
        film_kutuphanesi.yonetmen_goster()
    elif islem == "6":
        film_kutuphanesi.film_goster()
    elif islem == "7":
        kullanici_adi = input("Silmek istediginiz kullanici adinizi girin: ")
        film_kutuphanesi.kullanici_sil(kullanici_adi)
    elif islem == "8":
        yonetmen_ad_soyad = input("Silmek istediginiz yonetmen adini girin: ")
        film_kutuphanesi.yonetmen_sil(yonetmen_ad_soyad)
    elif islem == "9":
        film_ad = input("Silmek istediginiz film adini girin: ")
        film_kutuphanesi.film_sil(film_adi)
    elif islem == "10":
        kullanici_adi = input("Guncellemek istediginiz kullanici adini girin: ")
        film_kutuphanesi.kullanici_guncelleme(kullanici_adi)
    elif islem == "11":
        yonetmen_adi = input("Guncellemek istediginiz yonetmenin adini soyadini girin: ")
        film_kutuphanesi.yonetmen_guncelleme(yonetmen_ad_soyad)
    elif islem == "12":
        filmin_adi = input("Güncellemek istediginiz film adini girin: ")
        film_kutuphanesi.film_guncelleme(film_adi)
    elif islem == "13":
        film = input("Aramak istediginiz film adini girin: ")
        filmm = film_kutuphanesi.film_aramak(film_adi)
        if film:
            film.bilgileri_goster
        else: 
            print("İlgili film bulunamadi.")
    elif islem == "14" or islem == "q" or islem == "Q":
        print("Uygulamadan cikis yapiliyor.")
        break
# Out:
# ************************************************** Film Yonetim Sistemi **************************************************
#
#         Lütfen yapacaginiz islemin numarasini girin:
#
#         1. Kullanici Ekle
#         2. Yonetmen Ekle
#         3. Film Ekle
#         4. Kullanici Listesi
#         5. Yonetmen Listesi
#         6. Film Listesi
#         7. Kullanici Sil
#         8. Yonetmen Sil
#         9. Film Sil
#         10. Kullanici Guncelleme
#         11. Yonetmen Guncelleme
#         12. Film Guncelleme
#         13. Film Arama
#         14. Cikis icin (Q-q)
#
# İslem numarasini girin: 2
# Yonetmen adini ve soyadini girin: halil yilmaz
# Yonetmen dogum yilini girin: 1999
# halil yilmaz basarili sekilde eklendi.
# ************************************************** Film Yonetim Sistemi **************************************************
#
#         Lütfen yapacaginiz islemin numarasini girin:
#
#         1. Kullanici Ekle
#         2. Yonetmen Ekle
#         3. Film Ekle
# ...
